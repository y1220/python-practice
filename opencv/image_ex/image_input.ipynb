# %%
from __future__ import print_function
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# Masking

#stop_img = cv2.cvtColor(cv2.imread('stop.jpg'), cv2.COLOR_BGR2RGB)
abs_path = os.path.abspath('image/stop.png')
#stop_img = cv2.cvtColor(cv2.imread("opencv/sample_pics/stop.png"), cv2.COLOR_BGR2RGB)
stop_img = cv2.cvtColor(cv2.imread(abs_path), cv2.COLOR_BGR2RGB)

plt.figure(figsize=(12, 3))
plt.subplot(1,3,1)
plt.imshow(stop_img)

plt.subplot(1,3,2)
red_channel = stop_img[:,:,0]
plt.imshow(red_channel, cmpa= "gray")

plt.subplot(1,3,3)
_, thresh = cv2.threshold(red_channel, 120, 255, cv2.THRESH_BINARY)
plt.imshow(thresh, cmap= 'gray')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-5d5092856726> in <module>
#      21 plt.subplot(1,3,2)
#      22 red_channel = stop_img[:,:,0]
# ---> 23 plt.imshow(red_channel, cmpa= "gray")
#      24
#      25 plt.subplot(1,3,3)
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
pip install opencv-contrib-python-headless
# Out:
# ...
#      |████████████████████████████████| 43.6 MB 6.4 MB/s eta 0:00:011   |███████                         | 9.5 MB 9.2 MB/s eta 0:00:04     |████████▋                       | 11.7 MB 9.2 MB/s eta 0:00:04     |███████████████████████████     | 36.7 MB 9.4 MB/s eta 0:00:01     |███████████████████████████▍    | 37.3 MB 9.4 MB/s eta 0:00:01     |█████████████████████████████▎  | 39.9 MB 9.4 MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
img = cv2.imread('lena.jpg')
mask = cv2.imread('mask.png',0)
res = cv2.bitwise_and(img,img,mask = mask)

# %%
_, mask = cv.threshold(im_gray, thresh=180, maxval=255, type=cv.THRESH_BINARY)
im_thresh_gray = cv.bitwise_and(im_gray, mask)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7e0f0f61d472> in <module>
# ----> 1 _, mask = cv.threshold(im_gray, thresh=180, maxval=255, type=cv.THRESH_BINARY)
#       2 im_thresh_gray = cv.bitwise_and(im_gray, mask)
#
# NameError: name 'im_gray' is not defined

# %%
import cv2 as cv

im_color = cv.imread("lena.png", cv.IMREAD_COLOR)
im_gray = cv.cvtColor(im_color, cv.COLOR_BGR2GRAY)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-13-69e6b72197e5> in <module>
#       2
#       3 im_color = cv.imread("lena.png", cv.IMREAD_COLOR)
# ----> 4 im_gray = cv.cvtColor(im_color, cv.COLOR_BGR2GRAY)
#
# error: OpenCV(4.5.1) /tmp/pip-req-build-n24k10t1/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import cv2 as cv
import numpy as np
cap = cv.VideoCapture(0)
while(1):
    # Take each frame
    _, frame = cap.read()
    # Convert BGR to HSV
    hsv = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
    # define range of blue color in HSV
    lower_blue = np.array([110,50,50])
    upper_blue = np.array([130,255,255])
    # Threshold the HSV image to get only blue colors
    mask = cv.inRange(hsv, lower_blue, upper_blue)
    # Bitwise-AND mask and original image
    res = cv.bitwise_and(frame,frame, mask= mask)
    cv.imshow('frame',frame)
    cv.imshow('mask',mask)
    cv.imshow('res',res)
    k = cv.waitKey(5) & 0xFF
    if k == 27:
        break
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-913b4a5e37b7> in <module>
#       6     _, frame = cap.read()
#       7     # Convert BGR to HSV
# ----> 8     hsv = cv.cvtColor(frame, cv.COLOR_BGR2HSV)
#       9     # define range of blue color in HSV
#      10     lower_blue = np.array([110,50,50])
#
# error: OpenCV(4.5.1) /tmp/pip-req-build-n24k10t1/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
import cv2
color = cv2.imread("butterfly.jpg", 1 )

# %%
print(color)
# Out:
# None

# %%
if np.shape(img) == (): # latest numpy / py3
# Out:
#   File "<ipython-input-7-97bb7d641138>", line 1
#     if np.shape(img) == (): # latest numpy / py3
#                                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
abs_path
# Out:
# '/opencv/sample_pics/stop.png'

# %%
pwd
# Out:
# '/work'

# %%
ls
# Out:
# Untitled.ipynb   detect_number.ipynb  second_trial.ipynb
# Untitled1.ipynb  firstbook.ipynb

# %%
ls ..
# Out:
# bin@   dev/  home/  lib32@  libx32@  mnt/  proc/  run/   srv/  tmp/  var/
# boot/  etc/  lib@   lib64@  media/   opt/  root/  sbin@  sys/  usr/  work/

# %%
ls
