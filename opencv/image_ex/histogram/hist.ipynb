# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("data/src/Lena.jpg")
cv2.imshow("img", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# distribution of the coloring 
color_list = ["blue", "green", "red"]
for i,j in enumerate(color_list):
    hist = cv2.calcHist([img],[i], None, [256], [0,256])
    plt.plot(hist, color = j)
# from the output, we can tell the existence of big portion of red

# %%
img_gray = cv2.imread("data/src/Lena.jpg", 0)
hist2 = cv2.calcHist([img_gray], [0], None, [256], [0,256])
plt.plot(hist2)
